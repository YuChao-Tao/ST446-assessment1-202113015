# %% [markdown]
# # hive part

# %%
hive -f yelp.sql

# %% [markdown]
# ![1.png](attachment:1.png)

# %%
hive
add jar gs://st-work1-yuchao/hive-hcatalog-core-3.1.2.jar

# %% [markdown]
# ![2.png](attachment:2.png)

# %%
use yelp;
show tables;
describe yelptable;

# %% [markdown]
# ![3.png](attachment:3.png)

# %%
select count(*) from yelptable;

# %% [markdown]
# ![4.png](attachment:4.png)

# %%
Set hive.cli.print.header=true;
select name as Name, review_count as Review_count from academic order by review_count desc limit 10;

# %% [markdown]
# ![5.png](attachment:5.png)
